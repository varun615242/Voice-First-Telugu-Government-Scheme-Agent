# %%
def retrieve_myscheme(query: str) -> list:
    return [{
        "scheme": "ప్రధాన్ మంత్రి ఆవాస్ యోజన (PMAY)",
        "description": "ఇల్లు లేని వారికి ఇల్లు నిర్మించేందుకు ఆర్థిక సహాయం",
        "source": "https://www.myscheme.gov.in"
    }]

# %%
def retrieve_india_gov(query: str) -> list:
    return [{
        "scheme": "నేషనల్ సోషల్ అసిస్టెన్స్ ప్రోగ్రాం",
        "description": "వృద్ధులు, విధవలు మరియు వికలాంగులకు ఆర్థిక సహాయం",
        "source": "https://www.india.gov.in"
    }]

# %%
def retrieve_pmindia(query: str) -> list:
    return [{
        "scheme": "ప్రధాన్ మంత్రి ఆవాస్ యోజన",
        "description": "ప్రధానమంత్రి కార్యాలయం ఆధ్వర్యంలో అమలు చేసే నివాస పథకం",
        "source": "https://www.pmindia.gov.in"
    }]

# %%
def retrieve_nrega(query: str) -> list:
    if "ఉద్యోగ" in query or "పని" in query:
        return [{
            "scheme": "మహాత్మా గాంధీ జాతీయ గ్రామీణ ఉపాధి హామీ చట్టం (MGNREGA)",
            "description": "గ్రామీణ కుటుంబాలకు సంవత్సరానికి 100 రోజుల ఉపాధి హామీ",
            "source": "https://www.nrega.nic.in"
        }]
    return []

# %%
def retrieve_pmjay(query: str) -> list:
    if "వైద్య" in query or "ఆరోగ్య" in query:
        return [{
            "scheme": "ఆయుష్మాన్ భారత్ ప్రధాన్ మంత్రి జన ఆరోగ్య యోజన (PMJAY)",
            "description": "ఆరోగ్య చికిత్సకు ₹5 లక్షల వరకు బీమా కవరేజ్",
            "source": "https://www.pmjay.gov.in"
        }]
    return []

# %%
def retrieve_pmkisan(query: str) -> list:
    if "రైతు" in query or "వ్యవసాయ" in query:
        return [{
            "scheme": "ప్రధాన్ మంత్రి కిసాన్ సమ్మాన్ నిధి (PM-KISAN)",
            "description": "రైతులకు సంవత్సరానికి ₹6000 ఆర్థిక సహాయం",
            "source": "https://www.pmkisan.gov.in"
        }]
    return []

# %%
def retrieve_govt_schemes(query: str) -> dict:
    """
    Retrieval System Tool:
    Searches across multiple official government portals.
    """

    results = []
    results.extend(retrieve_myscheme(query))
    results.extend(retrieve_india_gov(query))
    results.extend(retrieve_pmindia(query))
    results.extend(retrieve_nrega(query))
    results.extend(retrieve_pmjay(query))
    results.extend(retrieve_pmkisan(query))

    return {
        "query": query,
        "total_results": len(results),
        "sources_searched": [
            "myscheme.gov.in",
            "india.gov.in",
            "pmindia.gov.in",
            "nrega.nic.in",
            "pmjay.gov.in",
            "pmkisan.gov.in"
        ],
        "results": results
    }

# %%
def mock_apply_scheme_api(scheme_name: str) -> dict:
    """
    Mock API Tool: Simulates a government application service.
    """
    return {
        "scheme": scheme_name,
        "application_steps": [
            "myscheme.gov.in వెబ్‌సైట్‌ను సందర్శించండి",
            "పథకాన్ని ఎంపిక చేయండి",
            "ఆధార్ మరియు ఆదాయ ధృవీకరణ పత్రాలు అప్‌లోడ్ చేయండి",
            "దరఖాస్తును సమర్పించండి"
        ],
        "documents_required": [
            "ఆధార్ కార్డు",
            "ఆదాయ ధృవీకరణ పత్రం",
            "రేషన్ కార్డు"
        ]
    }

# %%
PLANNER_PROMPT = """
ROLE:
You are a Planner Agent for Indian Government Welfare Schemes.

OBJECTIVE:
Your job is to understand the user's query and decide which tools to call and in what order.

RESPONSIBILITIES:
1. వినియోగదారుడి ప్రశ్నను పూర్తిగా అర్థం చేసుకోవాలి
2. తప్పనిసరిగా ముందుగా retrieve_govt_schemes టూల్‌ను ఉపయోగించాలి
3. retrieve_govt_schemes ఫలితాల ఆధారంగా మాత్రమే mock_apply_scheme_api టూల్‌ను ఉపయోగించాలి
4. టూల్స్ ఉపయోగించిన క్రమాన్ని తప్పనిసరిగా పాటించాలి
5. సమాధానంగా కేవలం JSON మాత్రమే ఇవ్వాలి — ఎటువంటి వివరణ లేదా వచనం ఇవ్వకూడదు

AVAILABLE TOOLS:
- retrieve_govt_schemes(query)
- mock_apply_scheme_api(scheme_name)

TOOL USAGE RULES:
- retrieve_govt_schemes టూల్ తప్పనిసరిగా మొదటి దశలో ఉండాలి
- mock_apply_scheme_api టూల్ తప్పనిసరిగా రెండో దశలో ఉండాలి
- రెండవ టూల్‌లో scheme_name విలువ retrieve_govt_schemes ఫలితాల నుండి తీసుకోవాలి
- retrieve_govt_schemes లో లభించని పథకం పేరును ఉపయోగించకూడదు
- ఎటువంటి కొత్త సమాచారం ఊహించకూడదు

Note: give plain text no bold output allowed

RESPONSE FORMAT (MANDATORY):
{
  "steps": [
    {
      "tool": "retrieve_govt_schemes",
      "arguments": {
        "query": "<user query in Telugu>"
      }
    },
    {
      "tool": "mock_apply_scheme_api",
      "arguments": {
        "scheme_name": "<scheme name obtained from retrieve_govt_schemes results>"
      }
    }
  ]
}
"""

# %%
import json
import google.generativeai as genai
import os

genai.configure(api_key="AIzaSyBRWST5R3JJee7QH2v1KeYt_BP7wEZ3aac")

planner = genai.GenerativeModel(
    model_name="models/gemini-3-flash-preview",
    system_instruction=PLANNER_PROMPT
)

def planner_agent(user_text: str) -> dict:
    response = planner.generate_content(user_text)
    return json.loads(response.text)

# %%
TOOLS = {
    "retrieve_govt_schemes": retrieve_govt_schemes,
    "mock_apply_scheme_api": mock_apply_scheme_api
}


def execute_steps(steps: list) -> list:
    outputs = []
    for step in steps:
        tool_fn = TOOLS[step["tool"]]
        result = tool_fn(**step["arguments"])
        outputs.append(result)
    return outputs

# %%
answer_model = genai.GenerativeModel(
    model_name="models/gemini-3-flash-preview",
    system_instruction="""
మీరు ప్రభుత్వ పథకాల సమాచారం అందించే Agent.

నియమాలు:
- టూల్ ఫలితాల ఆధారంగా మాత్రమే సమాధానం ఇవ్వాలి
- కొత్త సమాచారం జోడించకూడదు
- మూలాన్ని పేర్కొనాలి
- సమాధానం తెలుగులో ఉండాలి
"""
)

def generate_answer_with_memory(user_text, tool_outputs, memory):
    prompt = f"""
CONVERSATION HISTORY:
{memory.get_formatted_memory()}

CURRENT USER QUERY:
{user_text}

TOOL OUTPUTS:
{tool_outputs}

RESPONSE RULES:
- టూల్ ఫలితాల ఆధారంగా మాత్రమే సమాధానం ఇవ్వాలి
- సంభాషణలో ఉన్న సందర్భాన్ని పరిగణనలోకి తీసుకోవాలి
- సమాధానం పూర్తిగా తెలుగులో ఉండాలి
- కొత్త సమాచారం ఊహించకూడదు
"""

    response = answer_model.generate_content(prompt)
    return response.text

# %%
class ConversationMemory:
    def __init__(self):
        self.history = []

    def add_user_message(self, text: str):
        self.history.append({
            "role": "user",
            "content": text
        })

    def add_agent_message(self, text: str):
        self.history.append({
            "role": "agent",
            "content": text
        })

    def get_formatted_memory(self) -> str:
        """
        Formats memory into a readable string for LLM prompts
        """
        formatted = ""
        for turn in self.history:
            prefix = "వినియోగదారు" if turn["role"] == "user" else "ఏజెంట్"
            formatted += f"{prefix}: {turn['content']}\n"
        return formatted

# %%
class ConversationMemory:
    def __init__(self, max_turns: int | None = None):
        """
        max_turns: Optional limit on number of stored turns
        """
        self.history = []
        self.max_turns = max_turns

    # -----------------------------
    # Append methods (NO overwrite)
    # -----------------------------
    def add_user_message(self, text: str):
        self._append("user", text)

    def add_agent_message(self, text: str):
        self._append("agent", text)

    def _append(self, role: str, text: str):
        self.history.append({
            "role": role,
            "content": text
        })

        # Optional trimming (keep latest turns only)
        if self.max_turns is not None:
            self.history = self.history[-self.max_turns:]

    # -----------------------------
    # Read methods
    # -----------------------------
    def get_formatted_memory(self) -> str:
        """
        Formats memory into a readable string for LLM prompts
        """
        formatted = ""
        for turn in self.history:
            prefix = "వినియోగదారు" if turn["role"] == "user" else "ఏజెంట్"
            formatted += f"{prefix}: {turn['content']}\n"
        return formatted.strip()

    def get_raw_memory(self) -> list:
        """
        Returns raw memory list (for debugging or logging)
        """
        return self.history.copy()

    # -----------------------------
    # Maintenance methods
    # -----------------------------
    def reset(self):
        """
        Clears all conversation history
        """
        self.history.clear()

    def size(self) -> int:
        """
        Returns number of stored turns
        """
        return len(self.history)

# %%
def agent_loop(user_text: str, memory: ConversationMemory):
    # Save user input
    memory.add_user_message(user_text)

    # Planner decides tool sequence
    plan = planner_agent(user_text)

    # Execute tools
    tool_outputs = execute_steps(plan["steps"])

    # Generate final answer using memory
    final_answer = generate_answer_with_memory(
        user_text,
        tool_outputs,
        memory
    )

    # Save agent response
    memory.add_agent_message(final_answer)

    return final_answer.replace("*", "")

# %%
memory = ConversationMemory()

query1 = "ఖచ్చితంగా, మీరు అడిగిన ఆడియో యొక్క తెలుగు ట్రాన్స్‌క్రిప్షన్ మరియు ఇంగ్లీష్ ఫోనెటిక్స్ ఇక్కడ ఉన్నాయి."
response1 = agent_loop(query1, memory)
print(response1)

query2 = "నాకు ప్రభుత్వ పథకానికి అప్లై చేయాలి, కానీ నేను ఏ పథకానికి అర్హుడినో నాకు తెలియదు."
response2 = agent_loop(query2, memory)
print(response2)
# Out:
# అందుబాటులో ఉన్న సమాచారం ప్రకారం, కొన్ని ముఖ్యమైన ప్రభుత్వ పథకాల వివరాలు ఇక్కడ ఉన్నాయి:
#
# 1. ప్రధాన్ మంత్రి ఆవాస్ యోజన (PMAY):
#    - వివరణ: ఇల్లు లేని వారికి ఇల్లు నిర్మించుకోవడానికి ఈ పథకం ద్వారా ఆర్థిక సహాయం అందించబడుతుంది.
#    - మూలం: [https://www.myscheme.gov.in](https://www.myscheme.gov.in), [https://www.pmindia.gov.in](https://www.pmindia.gov.in)
#
# 2. నేషనల్ సోషల్ అసిస్టెన్స్ ప్రోగ్రాం:
#    - వివరణ: వృద్ధులు, విధవలు మరియు వికలాంగులకు ఆర్థిక సహాయం అందించే లక్ష్యంతో ఈ పథకం రూపొందించబడింది.
#    - మూలం: [https://www.india.gov.in](https://www.india.gov.in)
#
# అవసరమైన పత్రాలు:
# - ఆధార్ కార్డు
# - ఆదాయ ధృవీకరణ పత్రం
# - రేషన్ కార్డు
#
# దరఖాస్తు చేసుకునే విధానం:
# - ముందుగా myscheme.gov.in వెబ్‌సైట్‌ను సందర్శించాలి.
# - మీకు కావలసిన పథకాన్ని ఎంపిక చేసుకోవాలి.
# - ఆధార్ కార్డు మరియు ఆదాయ ధృవీకరణ పత్రాలను అప్‌లోడ్ చేయాలి.
# - చివరగా దరఖాస్తును సమర్పించాలి.
# మీరు ఏ పథకానికి అర్హులో తెలుసుకోవడానికి మరియు దరఖాస్తు చేసుకోవడానికి అందుబాటులో ఉన్న సమాచారం ఇక్కడ ఉంది:
#
# ...

# %%
memory = ConversationMemory(max_turns=10)

# %%
memory.add_user_message(query1)
memory.add_agent_message(response1)

# %%
memory.history
# Out:
# [{'role': 'user',
#   'content': 'ఖచ్చితంగా, మీరు అడిగిన ఆడియో యొక్క తెలుగు ట్రాన్స్\u200cక్రిప్షన్ మరియు ఇంగ్లీష్ ఫోనెటిక్స్ ఇక్కడ ఉన్నాయి.'},
#  {'role': 'agent',
# ...

# %%
import os
import base64
import google.generativeai as genai

# ----------------------------------
# Configure Gemini
# ----------------------------------
genai.configure(api_key="AIzaSyBRWST5R3JJee7QH2v1KeYt_BP7wEZ3aac")

tts_model = genai.GenerativeModel(
    model_name="models/gemini-3-flash-preview"
)

# ----------------------------------
# Text to Speech using Gemini
# ----------------------------------
def telugu_text_to_speech(text: str, output_file="agent_response.wav"):
    """
    Converts Telugu text to speech using Gemini API
    and saves it as a WAV file.
    """

    prompt = f"""
Convert the following Telugu text into clear, natural spoken Telugu audio.
Speak slowly and clearly for a general audience.

TEXT:
{text}
"""

    response = tts_model.generate_content(
        prompt,
        generation_config={
            "response_mime_type": "audio/wav"
        }
    )

    # Extract base64 audio
    audio_base64 = response.candidates[0].content.parts[0].inline_data.data
    audio_bytes = base64.b64decode(audio_base64)

    # Save audio
    with open(output_file, "wb") as f:
        f.write(audio_bytes)

    print(f"🔊 Audio saved to {output_file}")
    return output_file

# %%
# !pip install gTTS
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 8.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: click
#     Found existing installation: click 8.3.1
#     Uninstalling click-8.3.1:
#       Successfully uninstalled click-8.3.1
# ...

# %%
from gtts import gTTS

# %% [markdown]
# Final Implementation

# %%
from gtts import gTTS

def telugu_text_to_speech(text: str, output_file="agent_response.mp3"):
    """
    Converts Telugu text to speech using gTTS (CPU-only).

    """

    tts = gTTS(
        text=text,
        lang="te",
        slow=False
    )

    tts.save(output_file)
    print(f"🔊 Audio saved to {output_file}")
    return output_file

# %%
telugu_text_to_speech(response2,"agent_response2.mp3")
# Out:
# 🔊 Audio saved to agent_response2.mp3
# 'agent_response2.mp3'
